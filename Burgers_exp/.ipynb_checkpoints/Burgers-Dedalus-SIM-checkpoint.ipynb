# %%
import sys
pdefind_path = "/Users/pongpisit/Desktop/research/PDE-FIND/"
sys.path.insert(0, pdefind_path)
from misc import h5file, pickle_load
from itertools import combinations

import os
from os.path import join as pjoin
from pathlib import Path
import yaml

import numpy as np
from jax import numpy as jnp
import matplotlib.pyplot as plt
import dedalus.public as d3
import sympy
import pandas as pd
from scipy.io import loadmat
from scipy.optimize import curve_fit
from jaxfit import CurveFit
from levenberg_marquardt import lm as lm_curve_fit
from functools import partial

def log_like_value(prediction, ground):                                                                                                               
    nobs = float(ground.shape[0])
    nobs2 = nobs / 2.0
    ssr = np.sum(np.abs(ground - prediction)**2)
    llf = -nobs2 * np.log(2 * np.pi) - nobs2 * np.log(ssr / nobs) - nobs2
    return llf

def BIC_AIC(prediction, ground, nparams, reg_func = lambda x: x):
    nparams = reg_func(nparams)
    llf = log_like_value(prediction, ground)
    return -2*llf + np.log(ground.shape[0])*nparams, -2*llf + 2*nparams

import re
from collections import Counter

def ef(c):
    if c > 1: return f"dx({ef(c-1)})"
    else: return "dx(u)"
    
def convert2dedalus(input_string):
    old_strings = set(re.findall(r"u_\d+", input_string))
    new_strings = [ef(s.count('1')) for s in old_strings]
    for o, n in zip(old_strings, new_strings):
        input_string = input_string.replace(o, n)
    return input_string

# %%
noise_lv = 30
complexity = 2

fp1 = "./IPI_output_files/PMS_data.h5"
fp2 = "./IPI_output_files/encoded_pde_names.yaml"

x = loadmat('../Datasets/burgers.mat')['x'][0]; print(x)
X_pre, best_subsets, un, y_pre = h5file(file_path=fp1, mode='r', 
                                                        return_dict=False)

with open(fp2, 'r') as f:
    config = yaml.load(f, yaml.Loader)
f.close()
encoded_feature_names = config["encoded_feature_names"]
encoded_pde_names = config["encoded_pde_names"]
all_subsets = list(combinations(range(len(config["encoded_feature_names"])), complexity))
# Out:
# [-8.     -7.9375 -7.875  -7.8125 -7.75   -7.6875 -7.625  -7.5625 -7.5
#  -7.4375 -7.375  -7.3125 -7.25   -7.1875 -7.125  -7.0625 -7.     -6.9375
#  -6.875  -6.8125 -6.75   -6.6875 -6.625  -6.5625 -6.5    -6.4375 -6.375
#  -6.3125 -6.25   -6.1875 -6.125  -6.0625 -6.     -5.9375 -5.875  -5.8125
#  -5.75   -5.6875 -5.625  -5.5625 -5.5    -5.4375 -5.375  -5.3125 -5.25
#  -5.1875 -5.125  -5.0625 -5.     -4.9375 -4.875  -4.8125 -4.75   -4.6875
#  -4.625  -4.5625 -4.5    -4.4375 -4.375  -4.3125 -4.25   -4.1875 -4.125
#  -4.0625 -4.     -3.9375 -3.875  -3.8125 -3.75   -3.6875 -3.625  -3.5625
#  -3.5    -3.4375 -3.375  -3.3125 -3.25   -3.1875 -3.125  -3.0625 -3.
#  -2.9375 -2.875  -2.8125 -2.75   -2.6875 -2.625  -2.5625 -2.5    -2.4375
#  -2.375  -2.3125 -2.25   -2.1875 -2.125  -2.0625 -2.     -1.9375 -1.875
#  -1.8125 -1.75   -1.6875 -1.625  -1.5625 -1.5    -1.4375 -1.375  -1.3125
#  -1.25   -1.1875 -1.125  -1.0625 -1.     -0.9375 -0.875  -0.8125 -0.75
#  -0.6875 -0.625  -0.5625 -0.5    -0.4375 -0.375  -0.3125 -0.25   -0.1875
#  -0.125  -0.0625  0.      0.0625  0.125   0.1875  0.25    0.3125  0.375
#   0.4375  0.5     0.5625  0.625   0.6875  0.75    0.8125  0.875   0.9375
#   1.      1.0625  1.125   1.1875  1.25    1.3125  1.375   1.4375  1.5
#   1.5625  1.625   1.6875  1.75    1.8125  1.875   1.9375  2.      2.0625
#   2.125   2.1875  2.25    2.3125  2.375   2.4375  2.5     2.5625  2.625
#   2.6875  2.75    2.8125  2.875   2.9375  3.      3.0625  3.125   3.1875
#   3.25    3.3125  3.375   3.4375  3.5     3.5625  3.625   3.6875  3.75
#   3.8125  3.875   3.9375  4.      4.0625  4.125   4.1875  4.25    4.3125
#   4.375   4.4375  4.5     4.5625  4.625   4.6875  4.75    4.8125  4.875
#   4.9375  5.      5.0625  5.125   5.1875  5.25    5.3125  5.375   5.4375
#   5.5     5.5625  5.625   5.6875  5.75    5.8125  5.875   5.9375  6.
#   6.0625  6.125   6.1875  6.25    6.3125  6.375   6.4375  6.5     6.5625
#   6.625   6.6875  6.75    6.8125  6.875   6.9375  7.      7.0625  7.125
#   7.1875  7.25    7.3125  7.375   7.4375  7.5     7.5625  7.625   7.6875
#   7.75    7.8125  7.875   7.9375]
# ['X_pre', 'best_subsets', 'un', 'y_pre']

# %%
all_subsets = list(combinations(range(len(config["encoded_feature_names"])), complexity))
scores = []
for s in all_subsets:
    inp = X_pre[:, s]
    w = np.linalg.lstsq(inp, y_pre, rcond=None)[0]
    scores.append(((y_pre-inp@w)**2).mean())
    
init_params = np.linalg.lstsq(X_pre[:, all_subsets[np.argmin(scores)]], 
                              y_pre, rcond=None)[0].flatten().astype(np.float64)

effective_terms = [convert2dedalus(config["encoded_feature_names"][i]) 
                   for i in all_subsets[np.argmin(scores)]]
# print(all_subsets[np.argmin(scores)])
print(effective_terms)
print(init_params)
# Out:
# ['dx(dx(u))', 'u*dx(u)']
# [ 0.10128807 -1.00533521]

# %%
# hof = pd.read_csv("./hall/hof.csv")
# equation = hof.iloc[np.argmax(hof["score"])]
# pysr_params = np.array(sorted([float(atom) for atom in sympy.sympify(equation.equation).atoms() if atom.is_number]))

# def initial_function(x, a, b): return np.exp(a*np.square(x+b))
# def jax_initial_function(x, a, b): return jnp.exp(a*jnp.square(x+b))

# recovered_params1 = np.array(CurveFit().curve_fit(jax_initial_function, x.flatten(), un[:, 0], 
#                                                   p0=pysr_params)[0])

# recovered_params2 = np.array(curve_fit(initial_function, x.flatten(), un[:, 0], 
#                                        p0=pysr_params, method='lm')[0])

# recovered_params3 = lm_curve_fit(np.round(pysr_params).reshape(-1, 1), 
#                                  x.flatten(), un[:, 0], 
#                                  lambda t,p: np.exp(p[0,0]*np.square(t+p[1,0])))[0].flatten()

# # pysr_params, recovered_params1, recovered_params2, recovered_params3 (recommended when finetuning)
# recovered_params = recovered_params1

# # initial_condition_function = partial(initial_function, a=-1.0, b=2.0) # GROUND
# initial_condition_function = partial(initial_function, a=recovered_params[0], b=recovered_params[1])

# pysr_params, recovered_params1, recovered_params2, recovered_params3

# # func = sympy.lambdify(args=sympy.symbols('x'), expr=equation.sympy_format)
# # equation.equation

# %%
equation = pickle_load("./hall/hof.pkl")
feyn_params = np.array(sorted([float(atom) for atom in sympy.sympify(equation).atoms() if atom.is_number]))
feyn_params = feyn_params[[0, 2, 3, 4]]

def initial_function(x, a, b, c, d):
    return c+d*np.exp(a*np.square(b*x-1))

def jax_initial_function(x, a, b, c, d):
    return c+d*jnp.exp(a*jnp.square(b*x-1))

recovered_params = np.array(CurveFit().curve_fit(jax_initial_function, x.flatten(), un[:, 0], 
                                                  p0=feyn_params)[0])

initial_condition_function = partial(initial_function, 
                                     a=recovered_params[0], 
                                     b=recovered_params[1], 
                                     c=recovered_params[2], 
                                     d=recovered_params[3])

recovered_params
# Out:
# pickle_load done
# 2023-06-04 21:25:07,516 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.000308990478515625 sec
# 2023-06-04 21:25:07,522 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-04 21:25:07,523 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-04 21:25:07,524 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'tpu': module 'jaxlib.xla_extension' has no attribute 'get_tpu_client'
# 2023-06-04 21:25:07,525 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.
# 2023-06-04 21:25:07,528 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.00040912628173828125 sec
# 2023-06-04 21:25:07,534 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0005152225494384766 sec
# 2023-06-04 21:25:07,536 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.0006010532379150391 sec
# 2023-06-04 21:25:07,538 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming square for pjit in 0.0003941059112548828 sec
# 2023-06-04 21:25:07,540 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.0003769397735595703 sec
# 2023-06-04 21:25:07,543 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0005650520324707031 sec
# 2023-06-04 21:25:07,546 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.0009000301361083984 sec
# 2023-06-04 21:25:07,552 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _broadcast_arrays for pjit in 0.0012631416320800781 sec
# 2023-06-04 21:25:07,554 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _where for pjit in 0.004499912261962891 sec
# 2023-06-04 21:25:07,556 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_residual_func for pjit in 0.02330327033996582 sec
# 2023-06-04 21:25:07,557 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming func_no_transform for pjit in 0.02506875991821289 sec
# 2023-06-04 21:25:07,609 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(func_no_transform) in 0.036013126373291016 sec
# 2023-06-04 21:25:07,620 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_residual_func for pjit in 0.004173994064331055 sec
# 2023-06-04 21:25:07,621 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming func_no_transform for pjit in 0.006164073944091797 sec
# 2023-06-04 21:25:07,623 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming wrap_func for pjit in 0.008152008056640625 sec
# 2023-06-04 21:25:07,642 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jac_func for pjit in 0.031215190887451172 sec
# 2023-06-04 21:25:07,645 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _broadcast_arrays for pjit in 0.0006971359252929688 sec
# 2023-06-04 21:25:07,646 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _where for pjit in 0.002682209014892578 sec
# 2023-06-04 21:25:07,648 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming atleast_2d for pjit in 0.0002841949462890625 sec
# 2023-06-04 21:25:07,649 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_jac for pjit in 0.03876996040344238 sec
# 2023-06-04 21:25:07,711 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(masked_jac) in 0.036559104919433594 sec
# 2023-06-04 21:25:07,713 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0005159378051757812 sec
# 2023-06-04 21:25:07,714 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.00041174888610839844 sec
# 2023-06-04 21:25:07,716 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming loss_function for pjit in 0.0035326480865478516 sec
# 2023-06-04 21:25:07,738 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(loss_function) in 0.01861095428466797 sec
# 2023-06-04 21:25:07,740 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0006611347198486328 sec
# 2023-06-04 21:25:07,742 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming compute_grad for pjit in 0.002557992935180664 sec
# 2023-06-04 21:25:07,765 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(compute_grad) in 0.019047975540161133 sec
# 2023-06-04 21:25:07,766 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.00023174285888671875 sec
# 2023-06-04 21:25:07,769 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0005030632019042969 sec
# 2023-06-04 21:25:07,770 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming compute_grad_hat for pjit in 0.0018990039825439453 sec
# 2023-06-04 21:25:07,785 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(compute_grad_hat) in 0.012325048446655273 sec
# 2023-06-04 21:25:07,789 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0008547306060791016 sec
# 2023-06-04 21:25:07,791 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _svd for pjit in 0.000576019287109375 sec
# 2023-06-04 21:25:07,801 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0008099079132080078 sec
# 2023-06-04 21:25:07,803 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming svd_no_bounds for pjit in 0.015475034713745117 sec
# 2023-06-04 21:25:07,856 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(svd_no_bounds) in 0.044992923736572266 sec
# 2023-06-04 21:25:07,859 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0005559921264648438 sec
# 2023-06-04 21:25:07,861 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0005738735198974609 sec
# 2023-06-04 21:25:07,864 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0004401206970214844 sec
# 2023-06-04 21:25:07,865 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming evaluate_quadratic1 for pjit in 0.006845235824584961 sec
# 2023-06-04 21:25:07,899 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(evaluate_quadratic1) in 0.029207706451416016 sec
# 2023-06-04 21:25:07,901 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.0003819465637207031 sec
# 2023-06-04 21:25:07,914 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(<lambda>) in 0.008919954299926758 sec
# 2023-06-04 21:25:07,916 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming isfinite for pjit in 0.00031113624572753906 sec
# 2023-06-04 21:25:07,918 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _reduce_all for pjit in 0.0006620883941650391 sec
# 2023-06-04 21:25:07,921 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming isfinite for pjit in 0.006266117095947266 sec
# 2023-06-04 21:25:07,953 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(isfinite) in 0.024197816848754883 sec
# 2023-06-04 21:25:07,959 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming covariance_svd for pjit in 0.0006608963012695312 sec
# 2023-06-04 21:25:07,991 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(covariance_svd) in 0.02611708641052246 sec
# array([-4.15259791e+00, -4.97142427e-01,  2.95012304e-03,  1.00797403e+00])

# %%
LHS = "dt(u)"; RHS = "="
for i, term in enumerate(effective_terms):
    if '*' not in term:
        # linear
        add_string = (lambda s: '+' if s < 0 else '-')(init_params[i])
        add_string = add_string + chr(97+i) + '*' + effective_terms[i]
        eval(compile(f"{chr(97+i)} = {abs(init_params[i])}", "<string>", "exec"))
        LHS = LHS + add_string
    else:
        # non-linear
        add_string = (lambda s: '-' if s < 0 else '+')(init_params[i])
        add_string = add_string + chr(97+i) + '*' + effective_terms[i]
        eval(compile(f"{chr(97+i)} = {abs(init_params[i])}", "<string>", "exec"))
        RHS = RHS + add_string 
problem_string = LHS+RHS
problem_string
# Out:
# 'dt(u)-a*dx(dx(u))=-b*u*dx(u)'

# %%
# Parameters
Lx = 8
spatial_domain = (-Lx, Lx)
Nx = 256
dealias = 1.5 # 3/2
stop_sim_time = 10
timestepper = d3.SBDF4
acc = 4
timestep = (4e-3)/acc
spatial_variable_name = 'x'
target_variable_name = 'u'
dtype = np.float64

# %%
# Bases
xcoord = d3.Coordinate(spatial_variable_name)
dist = d3.Distributor(xcoord, dtype=dtype)
xbasis = d3.RealFourier(xcoord, size=Nx, bounds=spatial_domain, dealias=dealias)
# Fields
u = dist.Field(name=target_variable_name, bases=xbasis)
# Substitutions
dx = lambda A: d3.Differentiate(A, xcoord)

# %%
# Problem
problem = d3.IVP([u], namespace=locals())
# problem.add_equation("dt(u) - a*dx(dx(u)) - b*dx(dx(dx(u))) = - u*dx(u)")
problem.add_equation(problem_string)

# Initial conditions
x = dist.local_grid(xbasis)
u['g'] = initial_condition_function(x)
# u['g'] = un[:, 0]

# %%
# Solver
solver = problem.build_solver(timestepper)
solver.stop_sim_time = stop_sim_time

# Main loop
u.change_scales(1)
u_list = [np.copy(u['g'])]
t_list = [solver.sim_time]
while solver.proceed:
    solver.step(timestep)
    if solver.iteration % (25*acc) == 0:
        u.change_scales(1)
        u_list.append(np.copy(u['g']))
        t_list.append(solver.sim_time)
spatial_var = x.ravel()
temporal_var = np.array(t_list).ravel()
simulated_var = np.array(u_list)
# Out:
# 2023-06-04 21:25:08,062 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+01/s
# 2023-06-04 21:25:10,890 solvers 0/1 INFO :: Simulation stop time reached.

# %%
# Plot
plt.figure()
plt.pcolormesh(spatial_var, temporal_var, simulated_var, shading='gouraud')
plt.xlim(spatial_domain[0], spatial_domain[1])
plt.ylim(0, stop_sim_time)
plt.xlabel('x')
plt.ylabel('t')
plt.title('u')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Information criterion

# %%
# load ref
u_clean = loadmat("/Users/pongpisit/Desktop/research/PDE-FIND/Datasets/burgers.mat")["usol"]
u_clean = u_clean.real
((simulated_var.T-un)**2).mean(), ((simulated_var.T-u_clean)**2).mean()
# Out:
# (0.00032225293031704793, 8.959782809856025e-06)

# %%
undenoised = False
if undenoised:
    np.random.seed(0)
    u_test = u_clean + 0.01*np.abs(noise_lv)*(u_clean.std())*np.random.randn(u_clean.shape[0], 
                                                                             u_clean.shape[1])
else:
    u_test = un.copy()
    
bic, aic = BIC_AIC(simulated_var.T.reshape(-1, 1), u_test.reshape(-1, 1), complexity)
complexity, bic, aic
# Out:
# (2, -134490.26433945593, -134506.58493537857)

# %%
undenoised = True
if undenoised:
    np.random.seed(0)
    u_test = u_clean + 0.01*np.abs(noise_lv)*(u_clean.std())*np.random.randn(u_clean.shape[0], 
                                                                             u_clean.shape[1])
else:
    u_test = un.copy()
    
bic, aic = BIC_AIC(simulated_var.T.reshape(-1, 1), u_test.reshape(-1, 1), complexity)
complexity, bic, aic
# Out:
# (2, -77545.87895224187, -77562.19954816451)

# %%
##### Dedalus3 #####
### raw values un[:, 0] as IC *** ###
# (2, -134136.20432518743, -134152.52492111007) on denoised
# (3, -134054.41186380573, -134078.8927576897) on denoised
# (2, -77585.47558335702, -77601.79617927967) on undenoised
# (3, -77564.91264748888, -77589.39354137283) on undenoised
### Adjusted IC ###
## pysr -> params1 (Best adjusted IC)
# (2, -134836.34539162688, -134852.66598754952) on denoised
# (3, -134922.1076568017, -134946.58855068567) on denoised
# (2, -77579.8064492258, -77596.12704514845) on undenoised
# (3, -77577.701243085, -77602.18213696896)on undenoised
## feyn -> params1 (Best adjusted IC) ***
# (2, -134490.2643394553, -134506.58493537793) on denoised
# (3, -134150.24673856655, -134174.72763245052) on denoised
# (2, -77545.87895224181, -77562.19954816446) on undenoised
# (3, -77496.65965734256, -77521.14055122652) on undenoised
