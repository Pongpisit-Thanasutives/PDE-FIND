# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import random
import arviz as az
import pymc as pm
import pymc.sampling.jax as pmjax
import numpy as np

import sys; sys.path.append('../')
from rh_prior import horseshoe_prior
from misc import h5file
import yaml
import statsmodels.api as sm

# %%
noise_lv = 30
fp1 = "./IPI_output_files/PMS_data.h5"
fp2 = "./IPI_output_files/encoded_pde_names.yaml"
X_pre, best_subsets, un, y_pre = h5file(file_path=fp1, mode='r', return_dict=False)

with open(fp2, 'r') as f:
    config = yaml.load(f, yaml.Loader)
f.close()
encoded_feature_names = config["encoded_feature_names"]
encoded_pde_names = config["encoded_pde_names"]
encoded_pde_names
# Out:
# ['X_pre', 'best_subsets', 'un', 'y_pre']
# ['u*u_1',
#  'u_11+u*u_1',
#  'u_1+u_11+u*u_1',
#  'u_1+u_11+u*u_1+u*u*u_11',
#  'u+u*u+u_1+u_11+u*u_1',
#  'u+u*u+u_1+u_11+u*u_1+u*u*u_11',
#  'u+u*u+u_1+u_11+u*u_1+u*u_11+u*u*u_11',
#  'u+u*u+u_1+u_11+u*u_1+u*u*u_1+u*u_11+u*u*u_11']

# %%
hie = [np.where(best_subsets[i]>0)[0].tolist() for i in range(best_subsets.shape[-1])]

# %%
# Define the Bayesian linear regression model
map_est = np.linalg.lstsq(X_pre, y_pre, rcond=-1)[0]
init_sigma = np.mean((X_pre@map_est-y_pre)**2)
n_samples = 4000
X_sup = X_pre
y_sup = y_pre.ravel()
support_sizes = X_sup.shape[-1]

slab_df = 4
slab_scale = 2
tau0 = 1e-3

np.random.seed(0)
with pm.Model() as model:
    tau = pm.HalfStudentT('tau', nu=1, sigma=tau0)
    c2 = pm.InverseGamma('c2', alpha=0.5*slab_df, beta=0.5*slab_df*slab_scale**2)
    l = pm.HalfStudentT('l', nu=1, sigma=1, shape=support_sizes)
    lt = (pm.math.sqrt(c2)*l) / pm.math.sqrt(c2 + pm.math.sqr(tau) * pm.math.sqr(l))
    z  = pm.Normal('z', mu=0, sigma=1, shape=support_sizes)
    pn = pm.Deterministic('pn', z*tau*lt)
    coeffs = pm.Deterministic('coeffs', z*tau*lt)
    
#     coeffs = horseshoe_prior(X_sup, tau0, slab_df, slab_scale)
    
    sigma = pm.Exponential('sigma', lam=init_sigma)
    mu = pm.math.dot(X_sup, coeffs)
    likelihood = pm.Normal('y', mu=mu, sigma=sigma, observed=y_sup)

    # Perform MCMC sampling
#     trace = pm.sample(n_samples, tune=n_samples//2, chains=4, cores=4, 
#                       # nuts={'target_accept':0.99}, 
#                       nuts={'target_accept':0.99, 'max_treedepth':12}, 
#                       return_inferencedata=True)
    # trace = pmjax.sample_numpyro_nuts(n_samples, tune=n_samples//2, chains=4, cores=4, return_inferencedata=True)
    trace = pmjax.sample_blackjax_nuts(n_samples, tune=n_samples//2, chains=4, cores=4, return_inferencedata=True)
    pm.compute_log_likelihood(trace)
    idata = pm.sample_smc(draws=n_samples, progressbar=False, cores=4)
# Out:
# Compiling...
# Compilation time =  0:00:02.610621
# Sampling...
# Sampling time =  0:00:05.498228
# Transforming variables...
# Transformation time =  0:06:09.426137
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='16000' class='' max='16000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16000/16000 00:03&lt;00:00]
#     </div>
# ...

# %%
trace.to_netcdf("burgers_rh.trace", overwrite_existing=True)
idata.to_json("burgers_rh_idata.json")
# Out:
# 'burgers_rh_idata.json'

# %%
# trace = trace.from_netcdf("burgers_rh.trace")
post = trace.posterior

# %%
data = np.array(post.coeffs).reshape(-1, 8)
# uncert = np.abs(data.std(axis=0)/data.mean(axis=0))
uncert = np.abs(data.std(axis=0)/map_est.flatten())
uncert = uncert/min(uncert)
index = np.argsort(uncert)[:5]
data = data[:, index]

with plt.style.context(['science', 'grid']):
    plt.plot([i+1 for i in range(support_sizes)], uncert, 'o-', c='black', markerfacecolor='none')
    plt.xticks([i+1 for i in range(support_sizes)])
#     plt.title("Regularized horseshoe prior")
    plt.xlabel("$k^{\\textrm{th}}$ Candidate")
    plt.ylabel("Uncertainty factor")
    plt.savefig("../Figures/Burgers/rh_uncert.pdf")
    plt.show()

# %%
data = np.array(post.coeffs).reshape(-1, 8)
# uncert = np.abs(data.std(axis=0)/data.mean(axis=0))
uncert = np.abs(data.std(axis=0)/map_est.flatten())
uncert = uncert/min(uncert)
index = np.argsort(uncert)[:5]
data = data[:, index]

with plt.style.context(['science', 'grid']):
    plt.plot([i+1 for i in range(support_sizes)], uncert, 'o-', c='black', markerfacecolor='none')
    plt.xticks([i+1 for i in range(support_sizes)])
    plt.title("Regularized horseshoe prior")
    plt.xlabel("$k^{\\textrm{th}}$ Candidate")
    plt.ylabel("Uncertainty factor")
    plt.savefig("../Figures/Burgers/rh_uncert_title.pdf")
    plt.show()

# %%
[encoded_feature_names[i] for i in index], index # Set columns accordingly
# Out:
# (['u_11', 'u*u_1', 'u_1', 'u*u', 'u'], array([3, 4, 2, 1, 0]))

# %%
with plt.style.context(['science', 'grid']):
    sns.kdeplot(pd.DataFrame(data, columns=["$u_{xx}\checkmark$", "$uu_{x}\checkmark$", "$u_{x}$", "$u^{2}$", "$u$"]))
    plt.ylabel("Posterior distribution density")
    plt.xticks([-1., -0.5, 0, 0.1])
    plt.xlabel("Top 5 candidates' coefficient values")
    plt.savefig("../Figures/Burgers/rh_posterior.pdf")
    plt.show()

# %%
data = np.array(post.coeffs).reshape(-1, 8)
uncert = np.abs(data.std(axis=0)/map_est.flatten())
uncert = uncert/min(uncert)
index = np.argsort(uncert)[:5]
data = data[:, index]

with plt.style.context(['science', 'grid']):
    plt.plot([i+1 for i in range(support_sizes)], uncert, 'o-', c='black', markerfacecolor='none')
    plt.xticks([i+1 for i in range(support_sizes)])
#     plt.title("Regularized horseshoe prior")
    plt.xlabel("Support sizes ($s_{k}$)")
    plt.ylabel("$\\textrm{U}_{k}$")
#     plt.savefig("../Figures/Burgers/rh_uncert.pdf")
    plt.show()

# %%
[encoded_feature_names[i] for i in index], index # Set columns accordingly
# Out:
# (['u_11', 'u*u_1', 'u_1', 'u*u', 'u'], array([3, 4, 2, 1, 0]))

# %%
with plt.style.context(['science', 'grid']):
    sns.kdeplot(pd.DataFrame(data, columns=["$u_{xx}\checkmark$", "$uu_{x}\checkmark$", "$u_{x}$", "$u^{2}$", "$u$"]))
    plt.ylabel("Posterior distribution density")
    plt.xticks([-1., -0.5, 0, 0.1])
    plt.xlabel("Top 5 candidates' coefficient values")
#     plt.savefig("../Figures/Burgers/rh_posterior.pdf")
    plt.show()

# %%
# trace.to_netcdf("burgers_rh.trace", overwrite_existing=True)
# idata.to_json("burgers_rh_idata.json")
# Out:
# 'burgers_rh_idata.json'
