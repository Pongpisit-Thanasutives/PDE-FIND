# %%
import sys
pdefind_path = "/Users/pongpisit/Desktop/research/PDE-FIND/"
sys.path.insert(0, pdefind_path)
from misc import h5file

import jax.numpy as jnp
from scipy.optimize import curve_fit
from jaxfit import CurveFit
from levenberg_marquardt import lm as lm_curve_fit

import numpy as np
import pandas as pd
from scipy.io import loadmat
import sympy as sp
import matplotlib.pyplot as plt
import dedalus.public as d3

def log_like_value(prediction, ground):                                                                                                               
    nobs = float(ground.shape[0])
    nobs2 = nobs / 2.0
    ssr = np.sum(np.abs(ground - prediction)**2)
    llf = -nobs2 * np.log(2 * np.pi) - nobs2 * np.log(ssr / nobs) - nobs2
    return llf

def BIC_AIC(prediction, ground, nparams, reg_func = lambda x: x):
    nparams = reg_func(nparams)
    llf = log_like_value(prediction, ground)
    return -2*llf + np.log(ground.shape[0])*nparams, -2*llf + 2*nparams

# %%
# Parameters
Rx = 32*np.pi
Nx = 1024
Lx = Rx/Nx
dealias = 1.5
stop_sim_time = 100
timestepper = d3.SBDF4
acc = 16
timestep = 0.016/acc
dtype = np.float64

# %%
# Bases
xcoord = d3.Coordinate('x')
dist = d3.Distributor(xcoord, dtype=dtype)
xbasis = d3.RealFourier(xcoord, size=Nx, bounds=(Lx, Rx+Lx), dealias=dealias)

# Fields
u = dist.Field(name='u', bases=xbasis)

# Substitutions
dx = lambda A: d3.Differentiate(A, xcoord)

# %%
complexity = 3
X_pre, best_subsets, un, y_pre = h5file("./IPI_output_files/PMS_data.h5")
xaxis = loadmat("/Users/pongpisit/Desktop/research/PDE-FIND/Datasets/kuramoto_sivishinky.mat")['x']
if complexity == 3:
    # 0.9951430536784973 0.9966016871225765 0.9968154216196904
    a, b, c = np.abs(np.linalg.lstsq(X_pre[:, np.where(best_subsets[complexity-1]>0)[0]], y_pre, 
                                     rcond=None)[0].flatten())
    print(a, b, c)
elif complexity == 4:
    # 0.9952025550450707 0.0006388964618597726 0.9966536432642854 0.9968941888507773
    a, b, c, d = np.abs(np.linalg.lstsq(X_pre[:, np.where(best_subsets[complexity-1]>0)[0]], y_pre, 
                                        rcond=None)[0].flatten())
    print(a, b, c, d)
# Out:
# ['X_pre', 'best_subsets', 'un', 'y_pre']
# 0.9951430536784973 0.9966016871225765 0.9968154216196904

# %%
# Problem
problem = d3.IVP([u], namespace=locals())
# a, b, c = (1.0, 1.0, 1.0)
if complexity == 3:
    problem.add_equation("dt(u) + a*dx(dx(u)) + b*dx(dx(dx(dx(u)))) = - c*u*dx(u)")
elif complexity == 4:
    problem.add_equation("dt(u) + a*dx(dx(u)) - b*dx(dx(dx(u))) + c*dx(dx(dx(dx(u)))) = - d*u*dx(u)")

# %%
hall_path = "./hall/1/hall_of_fame_2023-05-27_145328.068.csv"
equation = pd.read_csv(hall_path)['Equation'].iloc[7]; print(equation)
at1, at2 = sp.sympify(equation).atoms(sp.Number)
if at1 > at2: at1, at2 = at2, at1
pysr_params = np.array([at1, at1, at2], dtype=dtype)
def initial_function(x, a, b, c): return np.cos(a*x)*(c+np.sin(b*x))
def jax_initial_function(x, a, b, c): return jnp.cos(a*x)*(c+jnp.sin(b*x))
pysr_params
# Out:
# (cos(0.062976345 * x0) * (0.9813761 + sin(0.062976345 * x0)))
# array([0.06297635, 0.06297635, 0.9813761 ])

# %%
lm_func = lambda t,p: np.cos(p[0,0]*t)*(p[2,0]+np.sin(p[1,0]*t))

recovered_params3 = lm_curve_fit(np.round(pysr_params.reshape(-1, 1), 1), 
                                 xaxis.flatten(), un[:, 0], 
                                 lm_func)[0].flatten()

# recovered_params1 and recovered_params2 gave similar results. Choose 1.
recovered_params2 = np.array(curve_fit(initial_function, xaxis.flatten(), un[:, 0], 
                                       p0=pysr_params, method='lm')[0])
recovered_params1 = np.array(CurveFit().curve_fit(jax_initial_function, xaxis.flatten(), un[:, 0], 
                                                  p0=pysr_params)[0])

pysr_params, recovered_params1, recovered_params2, recovered_params3
# Out:
# Using uniform weights for error analysis
# **** Convergence in Parameters ****
#
# LM fitting results:
# -----------------------------
# parameter      = p1
# fitted value   = 0.0594
# standard error = 0.70 %
# -----------------------------
# parameter      = p2
# fitted value   = 0.0592
# standard error = 0.70 %
# -----------------------------
# parameter      = p3
# fitted value   = 0.9879
# standard error = 0.04 %
# 2023-06-05 11:49:55,470 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.0002980232238769531 sec
# 2023-06-05 11:49:55,487 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-05 11:49:55,487 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-05 11:49:55,488 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'tpu': module 'jaxlib.xla_extension' has no attribute 'get_tpu_client'
# 2023-06-05 11:49:55,489 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.
# 2023-06-05 11:49:55,493 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.00026869773864746094 sec
# 2023-06-05 11:49:55,499 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0006079673767089844 sec
# 2023-06-05 11:49:55,501 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.00039505958557128906 sec
# 2023-06-05 11:49:55,503 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.00045490264892578125 sec
# 2023-06-05 11:49:55,506 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0010318756103515625 sec
# 2023-06-05 11:49:55,509 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0007817745208740234 sec
# 2023-06-05 11:49:55,512 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.0009081363677978516 sec
# 2023-06-05 11:49:55,517 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _broadcast_arrays for pjit in 0.0015912055969238281 sec
# 2023-06-05 11:49:55,518 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _where for pjit in 0.004090785980224609 sec
# 2023-06-05 11:49:55,520 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_residual_func for pjit in 0.022211074829101562 sec
# 2023-06-05 11:49:55,521 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming func_no_transform for pjit in 0.024283885955810547 sec
# 2023-06-05 11:49:55,868 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(func_no_transform) in 0.2972869873046875 sec
# 2023-06-05 11:49:55,876 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_residual_func for pjit in 0.002721071243286133 sec
# 2023-06-05 11:49:55,877 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming func_no_transform for pjit in 0.0038678646087646484 sec
# 2023-06-05 11:49:55,878 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming wrap_func for pjit in 0.00516510009765625 sec
# 2023-06-05 11:49:55,893 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jac_func for pjit in 0.022777080535888672 sec
# 2023-06-05 11:49:55,895 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _broadcast_arrays for pjit in 0.0005061626434326172 sec
# 2023-06-05 11:49:55,896 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _where for pjit in 0.0021300315856933594 sec
# 2023-06-05 11:49:55,898 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming atleast_2d for pjit in 0.00020003318786621094 sec
# 2023-06-05 11:49:55,899 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_jac for pjit in 0.02927994728088379 sec
# 2023-06-05 11:49:55,950 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(masked_jac) in 0.031286001205444336 sec
# 2023-06-05 11:49:55,953 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0008382797241210938 sec
# 2023-06-05 11:49:55,956 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0007631778717041016 sec
# 2023-06-05 11:49:55,957 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming loss_function for pjit in 0.0055658817291259766 sec
# 2023-06-05 11:49:55,983 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(loss_function) in 0.021773099899291992 sec
# 2023-06-05 11:49:55,985 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0005669593811035156 sec
# 2023-06-05 11:49:55,987 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming compute_grad for pjit in 0.0022902488708496094 sec
# 2023-06-05 11:49:56,011 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(compute_grad) in 0.02105116844177246 sec
# 2023-06-05 11:49:56,014 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.0005059242248535156 sec
# 2023-06-05 11:49:56,016 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0006480216979980469 sec
# 2023-06-05 11:49:56,017 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming compute_grad_hat for pjit in 0.0021359920501708984 sec
# 2023-06-05 11:49:56,034 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(compute_grad_hat) in 0.013171195983886719 sec
# 2023-06-05 11:49:56,036 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0007317066192626953 sec
# 2023-06-05 11:49:56,038 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _svd for pjit in 0.00061798095703125 sec
# 2023-06-05 11:49:56,040 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0007472038269042969 sec
# 2023-06-05 11:49:56,043 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming svd_no_bounds for pjit in 0.008136987686157227 sec
# 2023-06-05 11:49:56,099 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(svd_no_bounds) in 0.04599118232727051 sec
# 2023-06-05 11:49:56,102 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0007739067077636719 sec
# 2023-06-05 11:49:56,106 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0007011890411376953 sec
# 2023-06-05 11:49:56,109 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0004858970642089844 sec
# 2023-06-05 11:49:56,110 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming evaluate_quadratic1 for pjit in 0.008692026138305664 sec
# 2023-06-05 11:49:56,152 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(evaluate_quadratic1) in 0.03618788719177246 sec
# 2023-06-05 11:49:56,154 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.00047087669372558594 sec
# 2023-06-05 11:49:56,167 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(<lambda>) in 0.009382247924804688 sec
# 2023-06-05 11:49:56,169 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming isfinite for pjit in 0.00029206275939941406 sec
# 2023-06-05 11:49:56,171 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _reduce_all for pjit in 0.0005440711975097656 sec
# 2023-06-05 11:49:56,172 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming isfinite for pjit in 0.003074169158935547 sec
# 2023-06-05 11:49:56,207 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(isfinite) in 0.029393911361694336 sec
# 2023-06-05 11:49:56,211 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming covariance_svd for pjit in 0.0006079673767089844 sec
# 2023-06-05 11:49:56,242 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(covariance_svd) in 0.02360391616821289 sec
# (array([0.06297635, 0.06297635, 0.9813761 ]),
#  array([0.06263812, 0.06286727, 0.9839311 ]),
#  array([0.06263812, 0.06286727, 0.9839311 ]),
#  array([0.05936273, 0.05919549, 0.98790786]))

# %%
# pysr_params, recovered_params1, recovered_params2, recovered_params3
recovered_params = recovered_params1
# Initial conditions
x = dist.local_grid(xbasis)
# u['g'] = np.cos(x/16)*(1+np.sin(x/16))

### pub ###
# u['g'] = np.cos(recovered_params[0]*x)*(recovered_params[2]+np.sin(recovered_params[1]*x))


u['g'] = un[:, 0]

# %%
# Solver
solver = problem.build_solver(timestepper)
solver.stop_sim_time = stop_sim_time

# Main loop
u.change_scales(1)
u_list = [np.copy(u['g'])]
t_list = [solver.sim_time]
while solver.proceed:
    solver.step(timestep)
    if solver.iteration%(25*acc) == 0:
        u.change_scales(1)
        u_list.append(np.copy(u['g']))
        t_list.append(solver.sim_time)

spatial_var = x.ravel()
temporal_var = np.array(t_list).ravel()
simulated_var = np.array(u_list)
# Out:
# 2023-06-05 11:49:56,300 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.9e+01/s
# 2023-06-05 11:50:27,581 solvers 0/1 INFO :: Simulation stop time reached.

# %%
# Plot
plt.figure(figsize=(6, 4))
plt.pcolormesh(spatial_var, temporal_var, simulated_var, cmap='coolwarm', shading='gouraud', rasterized=True, clim=(-0.8, 0.8))
plt.xlim(0, Rx)
plt.ylim(0, stop_sim_time)
plt.xlabel('x')
plt.ylabel('t')
plt.show()
# plt.tight_layout()

# %% [markdown]
# #### Information criterion

# %%
# load ref
data = loadmat("/Users/pongpisit/Desktop/research/PDE-FIND/Datasets/kuramoto_sivishinky.mat")
u_clean = data["uu"]
u_clean = u_clean.real
xaxis = data['x'].real.ravel()
taxis = data['tt'].real.ravel()

# %%
# true: (1.092824632133786e-11, (-5757761.126348342, -5757792.497122576))
((simulated_var.T-u_clean)**2).mean(), BIC_AIC(simulated_var.T.reshape(-1, 1), u_clean.reshape(-1, 1), 3)
# Out:
# (2.262029055747076, (939238.8674360834, 939207.4966618492))

# %%
pred = simulated_var.T # simulated_var.T, cf_usol
# pred = cf_usol

# %%
noise_lv = 30
on_undenoised = False
if on_undenoised:
    np.random.seed(0)
    u_test = u_clean + 0.01*np.abs(noise_lv)*(u_clean.std())*np.random.randn(u_clean.shape[0], 
                                                                             u_clean.shape[1])
else:
    u_test = un.copy()
    
bic, aic = BIC_AIC(pred.reshape(-1, 1), u_test.reshape(-1, 1), complexity)
complexity, bic, aic
# Out:
# (3, 939694.1722593242, 939662.80148509)

# %%
noise_lv = 30
on_undenoised = True
if on_undenoised:
    np.random.seed(0)
    u_test = u_clean + 0.01*np.abs(noise_lv)*(u_clean.std())*np.random.randn(u_clean.shape[0], 
                                                                             u_clean.shape[1])
else:
    u_test = un.copy()
    
bic, aic = BIC_AIC(pred.reshape(-1, 1), u_test.reshape(-1, 1), complexity)
complexity, bic, aic
# Out:
# (3, 950743.02528723, 950711.6545129959)

# %%
##### Dedalus3 (pred = simulated_var.T) #####
### raw values un[:, 0] as IC *** ###
# (3, 939694.1722609766, 939662.8014867424) on denoised
# (4, 968190.4618845284, 968148.6341855495) on denoised
# (3, 950743.0252888124, 950711.6545145782) on undenoised
# (4, 978106.5687099883, 978064.7410110093) on undenoised
### pysr_params IC ###
# (3, 803185.643152019, 803154.2723777848) on denoised
# (4, 779213.6691787682, 779171.8414797892) on denoised
# (3, 821716.647611001, 821685.2768367669) on undenoised
# (4, 799477.7687019842, 799435.9410030053) on undenoised
### Adjusted IC ###
## params1 (Best adjusted IC) ***
# (3, 783458.9685251904, 783427.5977509562) on denoised
# (4, 811910.3272131429, 811868.4995141639) on denoised
# (3, 803400.5704714309, 803369.1996971967) on undenoised
# (4, 829826.8625591999, 829785.034860221) on undenoised
## params2 (Best adjusted IC)
# (3, 783458.9907923832, 783427.620018149) on denoised
# (4, 811910.3259884643, 811868.4982894853) on denoised
# (3, 803400.5911657464, 803369.2203915123) on undenoised
# (4, 829826.861417452, 829785.033718473) on undenoised
## params3
# (3, 886732.4482964904, 886701.0775222562) on denoised
# (4, 895679.9103753887, 895638.0826764097) on denoised
# (3, 900252.8444702567, 900221.4736960225) on undenoised
# (4, 908750.5194537467, 908708.6917547678) on undenoised

# %% [markdown]
# #### Unused

# %%
# # load cf true
# cf = loadmat("/Users/pongpisit/Desktop/research/PDE-FIND/DeepHPMs/Matlab/ks_chaotic.mat")
# cf_usol = cf['usol']
# ((cf_usol-u_clean)**2).mean(), BIC_AIC(cf_usol.reshape(-1, 1), u_clean.reshape(-1, 1), 3)

# # load cf
# cf = loadmat("/Users/pongpisit/Desktop/research/PDE-FIND/DeepHPMs/Matlab/KS_sim/ks_chaotic_sim_com4.mat")
# cf = loadmat("/Users/pongpisit/Desktop/research/PDE-FIND/DeepHPMs/Matlab/KS_sim/ks_chaotic_sim_adjustedIC_com4.mat")
# cf_usol = cf['usol']
# ((cf_usol-u_clean)**2).mean(), BIC_AIC(cf_usol.reshape(-1, 1), u_clean.reshape(-1, 1), 3)

# print(((simulated_var.T-cf_usol)**2).mean())
# plt.figure(figsize=(6, 4))
# plt.pcolormesh(cf['x'].ravel(), cf['t'].ravel(), cf_usol.T, cmap='coolwarm', shading='gouraud', rasterized=True, clim=(-0.8, 0.8))
# plt.xlim(0, Rx)
# plt.ylim(0, stop_sim_time)
# plt.xlabel('x')
# plt.ylabel('t')
# plt.show()

# %%
##### Chebfun (pred = cf_usol) #####
### pysr_params IC ###
# (3, 796688.596808223, 796657.2260339889) on denoised
# (4, 773154.477631851, 773112.649932872) on denoised
# --- #
# (3, 815671.8505524133, 815640.4797781791) on undenoised
# (4, 793886.9601944236, 793845.1324954446) on undenoised
### Adjusted IC ###
## params1
# (3, 829873.6793635229, 829842.3085892887) on denoised
# (4, 819650.1445381376, 819608.3168391587) on denoised
# (3, 846624.4711688751, 846593.1003946409) on undenoised
# (4, 837056.275441391, 837014.4477424121) on undenoised
