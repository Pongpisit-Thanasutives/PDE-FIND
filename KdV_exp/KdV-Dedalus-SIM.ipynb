# %%
import sys
sys.path.insert(0, "/Users/pongpisit/Desktop/research/PDE-FIND/")
from misc import h5file
from function_collections import BIC_AIC, msemse, colvec
sys.path.insert(0, "/Users/pongpisit/Desktop/research/parametric-discovery/")
from best_subset import brute_force, brute_force_all_subsets
from sklearn.linear_model import LinearRegression

import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as d3
from scipy.io import savemat, loadmat
import jax.numpy as jnp
from jaxfit import CurveFit

u_clean = loadmat("../Datasets/KdV_sine_rep_big.mat")['usol']
np.random.seed(0)
undenoised_u = u_clean + 0.01*np.abs(30)*(u_clean.std())*np.random.randn(u_clean.shape[0], u_clean.shape[1])
# Out:
# Sklearn's version: 1.2.2
# mrmr is not installed in the env you are using. This may cause an error in future if you try to use the (missing) lib.
# Best-subset solvers are NOT installed.

# %%
# u*u_1
# ----------
# u_111+u*u_1
# ----------
# u_111+u*u_1+u*u_111

complexity = 2
X_pre, best_subsets, un, y_pre = h5file("./IPI_output_files/PMS_data.h5")
xaxis = loadmat("/Users/pongpisit/Desktop/research/PDE-FIND/Datasets/KdV_sine_rep_big.mat")['x']
if complexity == 2:
    a, b = np.linalg.lstsq(X_pre[:, np.where(best_subsets[complexity-1]>0)[0]], 
                           y_pre, 
                           rcond=None)[0].flatten()
    print(a, b)
    a, b = np.abs([a, b])
elif complexity == 3:
    a, b, c = np.linalg.lstsq(X_pre[:, np.where(best_subsets[complexity-1]>0)[0]], y_pre, 
                              rcond=None)[0].flatten()
    print(a, b, c)
    a, b, c = np.abs([a, b, c])
# Out:
# ['X_pre', 'best_subsets', 'un', 'y_pre']
# -0.9037167644398507 -0.9103100649234885

# %%
# cws
use_cws = True
cws_IPI_data = loadmat("../WSINDy_PDE_latest/outputs/KdV/kdv30_ksvdreg_outputs.mat")
cws_W = cws_IPI_data['W']; print(cws_W)
cws_W = cws_W[abs(cws_W)>0]
cws_W[-1] = cws_W[-1]*2
cws_W = np.abs(cws_W)

rhs_desc = np.array([e.tolist() for e in cws_IPI_data['tags_pde_G'][0]])
rhs_desc = rhs_desc[1:]
X_cws = cws_IPI_data['oG'][:, 1:]
y_cws = cws_IPI_data['b']

if use_cws:
    cws_W = brute_force(X_cws, y_cws, complexity)
    cws_W3 = brute_force(X_cws, y_cws, 3)
    print(msemse(X_cws@cws_W, y_cws))
    cws_W = cws_W[abs(cws_W)>0]
    if complexity == 2:
        cws_W[-1] = cws_W[-1]*2
        print(cws_W)
        a, b = np.abs(cws_W)
    elif complexity == 3:
        cws_W[-1] = cws_W[-1]*2
        cws_W[-2] = cws_W[-2]*2
        print(cws_W)
        a, b, c = np.abs(cws_W)
# Out:
# [[ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [-0.9950437 ]
#  [ 0.        ]
#  [ 0.        ]
#  [-0.50073689]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# 772.2903101152643
# [-0.9950437  -1.00147377]

# %%
np.linalg.lstsq(np.hstack((X_cws[:, (3, 6)], np.ones_like(y_cws))), y_cws, rcond=None)
# Out:
# (array([[-0.99504237],
#         [-0.50073632],
#         [ 0.01624813]]),
#  array([1085839.8065239]),
#  3,
#  array([1.53572912e+05, 2.57417846e+04, 3.74113065e+01]))

# %%
# Parameters
Lx = 20
Nx = 512
dealias = 3/2
stop_sim_time = 40
timestepper = d3.SBDF2
timestep = 3.2e-3 # 4e-3
dtype = np.float64

# %%
# Bases
xcoord = d3.Coordinate('x')
dist = d3.Distributor(xcoord, dtype=dtype)
xbasis = d3.RealFourier(xcoord, size=Nx, bounds=(-Lx, Lx), dealias=dealias)

# %%
# Fields
u = dist.Field(name='u', bases=xbasis)

# %%
# Substitutions
dx = lambda A: d3.Differentiate(A, xcoord)

# %%
# Problem
problem = d3.IVP([u], namespace=locals())
# a, b = 0.9601505537264142, 0.9601505537264142
if complexity == 2:
    epsilon = (float(2*cws_W3[-2]))*(1e-2)
    # problem.add_equation("dt(u) + a*dx(dx(dx(u))) = -b*u*dx(u)")
    problem.add_equation("dt(u) + a*dx(dx(dx(u))) = -b*u*dx(u) + epsilon")
elif complexity == 3:
    problem.add_equation("dt(u) + a*dx(dx(dx(u))) = -b*u*dx(u) - c*u*dx(dx(dx(u)))")

# %%
# Initial conditions
x = dist.local_grid(xbasis)

### GROUND ##
# u['g'] = np.log(1 + np.cosh(n)**2/np.cosh(n*(x-0.2*Lx))**2) / (2*n)
# u['g'] = -np.sin(np.pi*x/20)

# u['g'] = undenoised_u[:, 0]
# u['g'] = un[:, 0]
# u['g'] = np.sin(-0.15645656*x)

# %%
def jax_initial_function(x, a): return jnp.sin(a*x)
# -0.15645656 = pysr_params init
recovered_params1 = np.array(CurveFit().curve_fit(jax_initial_function, 
                                                  xaxis.flatten(), 
                                                  un[:, 0], 
                                                  p0=[-0.15645656])[0])
u['g'] = np.sin(recovered_params1[0]*x)
# Out:
# 2023-07-19 22:40:13,896 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.00034308433532714844 sec
# 2023-07-19 22:40:13,905 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-07-19 22:40:13,906 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-07-19 22:40:13,907 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'tpu': module 'jaxlib.xla_extension' has no attribute 'get_tpu_client'
# 2023-07-19 22:40:13,908 jax._src.xla_bridge 0/1 INFO :: Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.
# 2023-07-19 22:40:13,913 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.0004780292510986328 sec
# 2023-07-19 22:40:13,918 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0005240440368652344 sec
# 2023-07-19 22:40:13,920 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.0006053447723388672 sec
# 2023-07-19 22:40:13,922 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.0005879402160644531 sec
# 2023-07-19 22:40:13,925 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _broadcast_arrays for pjit in 0.0009160041809082031 sec
# 2023-07-19 22:40:13,927 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _where for pjit in 0.0030977725982666016 sec
# 2023-07-19 22:40:13,929 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_residual_func for pjit in 0.011561870574951172 sec
# 2023-07-19 22:40:13,930 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming func_no_transform for pjit in 0.013273954391479492 sec
# 2023-07-19 22:40:13,969 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(func_no_transform) in 0.030138254165649414 sec
# 2023-07-19 22:40:13,978 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_residual_func for pjit in 0.002067089080810547 sec
# 2023-07-19 22:40:13,979 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming func_no_transform for pjit in 0.003589153289794922 sec
# 2023-07-19 22:40:13,980 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming wrap_func for pjit in 0.00539398193359375 sec
# 2023-07-19 22:40:13,994 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jac_func for pjit in 0.0229952335357666 sec
# 2023-07-19 22:40:13,998 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _broadcast_arrays for pjit in 0.0006880760192871094 sec
# 2023-07-19 22:40:14,000 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _where for pjit in 0.0031800270080566406 sec
# 2023-07-19 22:40:14,002 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming atleast_2d for pjit in 0.0003020763397216797 sec
# 2023-07-19 22:40:14,003 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming masked_jac for pjit in 0.03207707405090332 sec
# 2023-07-19 22:40:14,038 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(masked_jac) in 0.01910877227783203 sec
# 2023-07-19 22:40:14,041 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0006721019744873047 sec
# 2023-07-19 22:40:14,043 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0006530284881591797 sec
# 2023-07-19 22:40:14,045 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming loss_function for pjit in 0.0048770904541015625 sec
# 2023-07-19 22:40:14,066 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(loss_function) in 0.017780065536499023 sec
# 2023-07-19 22:40:14,071 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0009140968322753906 sec
# 2023-07-19 22:40:14,073 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming compute_grad for pjit in 0.002947092056274414 sec
# 2023-07-19 22:40:14,093 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(compute_grad) in 0.015610933303833008 sec
# 2023-07-19 22:40:14,096 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming jit(convert_element_type) in 0.0006392002105712891 sec
# 2023-07-19 22:40:14,099 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0006878376007080078 sec
# 2023-07-19 22:40:14,101 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming compute_grad_hat for pjit in 0.003385782241821289 sec
# 2023-07-19 22:40:14,118 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(compute_grad_hat) in 0.013267278671264648 sec
# 2023-07-19 22:40:14,124 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0013620853424072266 sec
# 2023-07-19 22:40:14,128 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _svd for pjit in 0.0006268024444580078 sec
# 2023-07-19 22:40:14,130 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0011513233184814453 sec
# 2023-07-19 22:40:14,132 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming svd_no_bounds for pjit in 0.009922027587890625 sec
# 2023-07-19 22:40:14,175 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(svd_no_bounds) in 0.03355884552001953 sec
# 2023-07-19 22:40:14,178 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0005600452423095703 sec
# 2023-07-19 22:40:14,180 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming dot for pjit in 0.0005769729614257812 sec
# 2023-07-19 22:40:14,183 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming fn for pjit in 0.0004811286926269531 sec
# 2023-07-19 22:40:14,184 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming evaluate_quadratic1 for pjit in 0.0071370601654052734 sec
# 2023-07-19 22:40:14,202 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(evaluate_quadratic1) in 0.012299776077270508 sec
# 2023-07-19 22:40:14,203 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming <lambda> for pjit in 0.00043582916259765625 sec
# 2023-07-19 22:40:14,217 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(<lambda>) in 0.010833024978637695 sec
# 2023-07-19 22:40:14,220 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming isfinite for pjit in 0.0004210472106933594 sec
# 2023-07-19 22:40:14,222 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming _reduce_all for pjit in 0.0007491111755371094 sec
# 2023-07-19 22:40:14,224 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming isfinite for pjit in 0.004264116287231445 sec
# 2023-07-19 22:40:14,254 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(isfinite) in 0.025342941284179688 sec
# 2023-07-19 22:40:14,259 jax._src.dispatch 0/1 WARNING :: Finished tracing + transforming covariance_svd for pjit in 0.0007688999176025391 sec
# 2023-07-19 22:40:14,282 jax._src.dispatch 0/1 WARNING :: Finished XLA compilation of jit(covariance_svd) in 0.015327930450439453 sec

# %%
recovered_params1[0]
# Out:
# -0.1564577903993788

# %%
# Solver
solver = problem.build_solver(timestepper)
solver.stop_sim_time = stop_sim_time
# Out:
# 2023-07-19 22:40:14,332 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.0e+01/s

# %%
# Main loop
u.change_scales(1)
u_list = [np.copy(u['g'])]
t_list = [solver.sim_time]
while solver.proceed:
    solver.step(timestep)
    if solver.iteration % 25 == 0:
        u.change_scales(1)
        u_list.append(np.copy(u['g']))
        t_list.append(solver.sim_time)
# Out:
# 2023-07-19 22:40:20,819 solvers 0/1 INFO :: Simulation stop time reached.

# %%
# Plot
plt.figure(figsize=(6, 4))
plt.pcolormesh(x.ravel(), np.array(t_list), np.array(u_list), cmap='RdBu_r', shading='gouraud', rasterized=True, clim=(-0.8, 0.8))
plt.xlim(-Lx, Lx)
plt.ylim(0, stop_sim_time)
plt.xlabel('x')
plt.ylabel('t')
plt.tight_layout()
# plt.savefig('kdv_burgers.pdf')
# plt.savefig('kdv_burgers.png', dpi=200)

# %%
xx = x.ravel().reshape(1, -1)
tt = np.array(t_list).reshape(1, -1)
usol = np.array(u_list).T

# %%
print(BIC_AIC(colvec(usol), colvec(un), complexity))
print(BIC_AIC(colvec(usol), colvec(undenoised_u), complexity))
print(BIC_AIC(colvec(usol), colvec(u_clean), complexity))
msemse(usol, un)
# Out:
# (-731844.6328064174, -731865.5426678697)
# (-67070.32397906213, -67091.23384051438)
# (-1449458.289565099, -1449479.1994265511)
# 0.0033760930200692966

# %%
lr = LinearRegression(fit_intercept=True)
lr.fit(colvec(usol), colvec(un))
BIC_AIC(lr.predict(colvec(usol)), colvec(un), complexity)
# Out:
# (-732596.0396559368, -732616.9495173891)

# %%
cf_sim_usol = loadmat("../DeepHPMs/Matlab/KdV_sim/kdv_sim_CWF_com2.mat")['usol']
print(BIC_AIC(colvec(cf_sim_usol), colvec(un), 2))
print(BIC_AIC(colvec(cf_sim_usol), colvec(undenoised_u), 2))
print(BIC_AIC(colvec(cf_sim_usol), colvec(u_clean), 2))
msemse(cf_sim_usol, un)
# Out:
# (-708448.7909222144, -708469.7007836667)
# (-65232.89169954239, -65253.801560994645)
# (-1204577.0537171022, -1204597.9635785543)
# 0.0036984977432581597

# %%
cf_sim_usol = loadmat("../DeepHPMs/Matlab/KdV_sim/kdv_sim_CWF_adjustedIC_com2.mat")['usol']
print(BIC_AIC(colvec(cf_sim_usol), colvec(un), 2))
print(BIC_AIC(colvec(cf_sim_usol), colvec(undenoised_u), 2))
print(BIC_AIC(colvec(cf_sim_usol), colvec(u_clean), 2))
msemse(cf_sim_usol, un)
# Out:
# (-708492.719848676, -708513.6297101283)
# (-65236.42854780784, -65257.33840926009)
# (-1204869.323983592, -1204890.2338450442)
# 0.003697864411779714

# %%
##### Use conv weak form (CWS), use sin in jaxfit IC *** #####
# com=2
# -708616.9509167484
# com=2 + epsilon
# -731844.6328064384
# com=3
# -722890.3221166723

# %%
##### Use conv weak form (CWS), use sin in IC *** #####
# com=2
# -708573.4574643458
# com=2 + epsilon
# -731810.7242479663
# com=3
# -721720.6679410206

# %%
##### Use weak form (WF), use sin in IC #####
# com=2
# (-2988.5631005058417, -3009.4729619580903) | (-2980.3167505971974, -3001.226612049446) [By chebfun]
# com=3
# (-81246.04026289746, -81277.40505507583)
