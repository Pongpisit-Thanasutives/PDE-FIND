# %%
import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as d3
from scipy.io import savemat, loadmat

# %%
# Parameters
Lx = 20
Nx = 512
dealias = 3/2
stop_sim_time = 40
timestepper = d3.RK443
timestep = 3.2e-3 # 4e-3
dtype = np.float64

# %%
# Bases
xcoord = d3.Coordinate('x')
dist = d3.Distributor(xcoord, dtype=dtype)
xbasis = d3.RealFourier(xcoord, size=Nx, bounds=(-Lx, Lx), dealias=dealias)

# %%
# Fields
u = dist.Field(name='u', bases=xbasis)

# %%
# Substitutions
dx = lambda A: d3.Differentiate(A, xcoord)

# %%
# Problem
problem = d3.IVP([u], namespace=locals())
problem.add_equation("dt(u) + dx(dx(dx(u))) = -u*dx(u)")
# Out:
# {'LHS': Add(dt(<Field 5035461264>), Diff(Diff(Diff(<Field 5035461264>)))),
#  'RHS': Mul(Mul(-1, <Field 5035461264>), Diff(<Field 5035461264>)),
#  'condition': 'True',
#  'tensorsig': (),
#  'dtype': dtype('float64'),
#  'M': <Field 5035461264>,
#  'L': Diff(Diff(Diff(<Field 5035461264>))),
#  'F': Mul(Mul(-1, <Field 5035461264>), Diff(<Field 5035461264>)),
#  'domain': <dedalus.core.domain.Domain at 0x12c231750>,
#  'matrix_dependence': array([ True]),
#  'matrix_coupling': array([False])}

# %%
# Initial conditions
x = dist.local_grid(xbasis)
n = 20
# u['g'] = np.log(1 + np.cosh(n)**2/np.cosh(n*(x-0.2*Lx))**2) / (2*n)
u['g'] = -np.sin(np.pi*x/n)

# %%
# Solver
solver = problem.build_solver(timestepper)
solver.stop_sim_time = stop_sim_time
# Out:
# 2023-06-25 17:36:01,325 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+01/s

# %%
# Main loop
u.change_scales(1)
u_list = [np.copy(u['g'])]
t_list = [solver.sim_time]
while solver.proceed:
    solver.step(timestep)
    if solver.iteration % 25 == 0:
        u.change_scales(1)
        u_list.append(np.copy(u['g']))
        t_list.append(solver.sim_time)
# Out:
# 2023-06-25 17:36:14,099 solvers 0/1 INFO :: Simulation stop time reached.

# %%
# Plot
plt.figure(figsize=(6, 4))
plt.pcolormesh(x.ravel(), np.array(t_list), np.array(u_list), cmap='RdBu_r', shading='gouraud', rasterized=True, clim=(-0.8, 0.8))
plt.xlim(-Lx, Lx)
plt.ylim(0, stop_sim_time)
plt.xlabel('x')
plt.ylabel('t')
plt.tight_layout()
# plt.savefig('kdv_burgers.pdf')
# plt.savefig('kdv_burgers.png', dpi=200)

# %%
xx = x.ravel().reshape(1, -1)
tt = np.array(t_list).reshape(1, -1)
usol = np.array(u_list).T

# %%
((loadmat('../Datasets/KdV_sine_rep_big.mat')['usol']-usol)**2).mean()
# Out:
# 3.848402563452281e-15

# %%
savemat("/Users/pongpisit/Desktop/research/PDE-FIND/Datasets/KdV_sine_rep_big_dedalus3.mat", 
        {'x':xx, 't':tt, 'usol':usol})
